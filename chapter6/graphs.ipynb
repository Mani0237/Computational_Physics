# %% [markdown]
# # Problem 2

# %%
import numpy as np
import matplotlib.pyplot as plt 

T = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
S = [2.00805, 2.01092, 2.01572, 2.02248, 2.03124, 2.04203, 2.05493, 2.06999, 2.08732, 2.10701]
S_exact = [2.00804, 2.0109, 2.01564, 2.02222, 2.0306, 2.0407, 2.05246, 2.06579, 2.08057, 2.09671]
error = [1.02311e-06, 1.63724e-05, 8.29078e-05, 0.000262133, 0.000640309, 0.00132864, 0.00246354, 0.00420701, 0.00674722, 0.0102992]
plt.plot(T,S)
plt.plot(T, S_exact)
plt.show()
plt.plot(T, error)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 

N = [8, 16, 32, 64]
error = [0.002938, 0.000984, 0.000496, 0.000374]
plt.loglog(N, error)
plt.show()
